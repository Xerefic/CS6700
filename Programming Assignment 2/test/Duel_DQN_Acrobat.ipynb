# %%
import gym
import torch
import torch.nn as nn
import numpy as np
from collections import deque
import random
from itertools import count
import torch.nn.functional as F
     
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class QNetwork(nn.Module):
    def __init__(self, n_state=4, n_action=2,type=1):
        super(QNetwork, self).__init__()

        self.fc1 = nn.Linear(n_state, 64)
        self.relu = nn.ReLU()
        self.fc_value = nn.Linear(64, 256)
        self.fc_adv = nn.Linear(64, 256)

        self.value = nn.Linear(256, 1)
        self.adv = nn.Linear(256, n_action)

        self.type = type

    def forward(self, state):
        y = self.relu(self.fc1(state))
        value = self.relu(self.fc_value(y))
        adv = self.relu(self.fc_adv(y))

        value = self.value(value)
        adv = self.adv(adv)

        advAverage = torch.mean(adv, dim=1, keepdim=True)
        advMax = torch.max(adv, dim=1, keepdim=True)
        if self.type == 1:
            Q = value + adv - advAverage
        elif self.type == 2:
            Q = value + adv - advMax
        return Q
    
    def select_action(self, state):
        with torch.no_grad():
            Q = self.forward(state)
            action_index = torch.argmax(Q, dim=1)
        return action_index.item()

# %%
class Memory(object):
    def __init__(self, memory_size: int) -> None:
        self.memory_size = memory_size
        self.buffer = deque(maxlen=self.memory_size)

    def add(self, experience) -> None:
        self.buffer.append(experience)

    def size(self):
        return len(self.buffer)

    def sample(self, batch_size: int, continuous: bool = True):
        if batch_size > len(self.buffer):
            batch_size = len(self.buffer)
        if continuous:
            rand = random.randint(0, len(self.buffer) - batch_size)
            return [self.buffer[i] for i in range(rand, rand + batch_size)]
        else:
            indexes = np.random.choice(np.arange(len(self.buffer)), size=batch_size, replace=False)
            return [self.buffer[i] for i in indexes]

    def clear(self):
        self.buffer.clear()

# %%
env = gym.make('Acrobot-v1')
# env = RecordVideo(gym.make("CartPole-v1"), "./mp4")
n_state = env.observation_space.shape[0]
n_action = env.action_space.n

onlineQNetwork = QNetwork(n_state=n_state, n_action=n_action).to(device)
targetQNetwork = QNetwork(n_state=n_state, n_action=n_action).to(device)
targetQNetwork.load_state_dict(onlineQNetwork.state_dict())

optimizer = torch.optim.Adam(onlineQNetwork.parameters(), lr=1e-4)

GAMMA = 0.99
EXPLORE = 20000
INITIAL_EPSILON = 0.1
FINAL_EPSILON = 0.0001
REPLAY_MEMORY = 50000
BATCH = 16

UPDATE_STEPS = 4

memory_replay = Memory(REPLAY_MEMORY)

epsilon = INITIAL_EPSILON
learn_steps = 0
begin_learn = False

episode_reward = 0

# %%
for epoch in range(600):

    state = env.reset()
    episode_reward = 0
    for time_steps in range(200):
        p = random.random()
        # _ = env.render()
        if p < epsilon:
            action = random.randint(0, 2)
        else:
            tensor_state = torch.FloatTensor(state).unsqueeze(0).to(device)
            action = onlineQNetwork.select_action(tensor_state)
        next_state, reward, done, _ = env.step(action)
        episode_reward += reward
        memory_replay.add((state, next_state, action, reward, done))
        if memory_replay.size() > 128:
            if begin_learn is False:
                print('learn begin!')
                begin_learn = True
            learn_steps += 1
            if learn_steps % UPDATE_STEPS == 0:
                targetQNetwork.load_state_dict(onlineQNetwork.state_dict())
            batch = memory_replay.sample(BATCH, False)
            batch_state, batch_next_state, batch_action, batch_reward, batch_done = zip(*batch)

            batch_state = torch.FloatTensor(batch_state).to(device)
            batch_next_state = torch.FloatTensor(batch_next_state).to(device)
            batch_action = torch.FloatTensor(batch_action).unsqueeze(1).to(device)
            batch_reward = torch.FloatTensor(batch_reward).unsqueeze(1).to(device)
            batch_done = torch.FloatTensor(batch_done).unsqueeze(1).to(device)

            with torch.no_grad():
                onlineQ_next = onlineQNetwork(batch_next_state)
                targetQ_next = targetQNetwork(batch_next_state)
                online_max_action = torch.argmax(onlineQ_next, dim=1, keepdim=True)
                y = batch_reward + (1 - batch_done) * GAMMA * targetQ_next.gather(1, online_max_action.long())

            loss = F.mse_loss(onlineQNetwork(batch_state).gather(1, batch_action.long()), y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # writer.add_scalar('loss', loss.item(), global_step=learn_steps)

            if epsilon > FINAL_EPSILON:
                epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        if done:
            break
        state = next_state

    # writer.add_scalar('episode reward', episode_reward, global_step=epoch)
    if epoch % 10 == 0:
        torch.save(onlineQNetwork.state_dict(), 'ddqn-policy.para')
        print('Ep {}\tMoving average score: {:.2f}\t'.format(epoch, episode_reward))
# Out:
# learn begin!
# Ep 0	Moving average score: -200.00
# Ep 10	Moving average score: -200.00
# Ep 20	Moving average score: -181.00
# Ep 30	Moving average score: -200.00
# Ep 40	Moving average score: -200.00
# Ep 50	Moving average score: -200.00
# Ep 60	Moving average score: -200.00
# Ep 70	Moving average score: -200.00
# Ep 80	Moving average score: -200.00
# Ep 90	Moving average score: -200.00
# Ep 100	Moving average score: -200.00
# Ep 110	Moving average score: -200.00
# Ep 120	Moving average score: -200.00
# Ep 130	Moving average score: -200.00
# Ep 140	Moving average score: -200.00
# Ep 150	Moving average score: -200.00
# Ep 160	Moving average score: -200.00
# Ep 170	Moving average score: -200.00
# Ep 180	Moving average score: -200.00
# Ep 190	Moving average score: -200.00
# Ep 200	Moving average score: -171.00
# Ep 210	Moving average score: -196.00
# Ep 220	Moving average score: -200.00
# Ep 230	Moving average score: -158.00
# Ep 240	Moving average score: -154.00
# Ep 250	Moving average score: -119.00
# Ep 260	Moving average score: -83.00
# Ep 270	Moving average score: -200.00
# Ep 280	Moving average score: -93.00
# Ep 290	Moving average score: -150.00
# Ep 300	Moving average score: -64.00
# Ep 310	Moving average score: -109.00
# Ep 320	Moving average score: -71.00
# Ep 330	Moving average score: -87.00
# Ep 340	Moving average score: -95.00
# Ep 350	Moving average score: -126.00
# Ep 360	Moving average score: -63.00
# Ep 370	Moving average score: -92.00
# Ep 380	Moving average score: -154.00
# Ep 390	Moving average score: -102.00
# Ep 400	Moving average score: -87.00
# Ep 410	Moving average score: -115.00
# Ep 420	Moving average score: -114.00
# Ep 430	Moving average score: -72.00
# Ep 440	Moving average score: -132.00
# Ep 450	Moving average score: -156.00
# Ep 460	Moving average score: -82.00
# Ep 470	Moving average score: -75.00
# Ep 480	Moving average score: -79.00
# Ep 490	Moving average score: -71.00
# Ep 500	Moving average score: -97.00
# Ep 510	Moving average score: -72.00
# Ep 520	Moving average score: -94.00
# Ep 530	Moving average score: -125.00
# Ep 540	Moving average score: -106.00
# Ep 550	Moving average score: -97.00
# Ep 560	Moving average score: -117.00
# Ep 570	Moving average score: -105.00
# Ep 580	Moving average score: -101.00
# Ep 590	Moving average score: -138.00

# %%
for epoch in range(600):

    state = env.reset()
    episode_reward = 0
    for time_steps in range(200):
        p = random.random()
        _ = env.render()
        if p < epsilon:
            action = random.randint(0, 2)
        else:
            tensor_state = torch.FloatTensor(state).unsqueeze(0).to(device)
            action = onlineQNetwork.select_action(tensor_state)
        next_state, reward, done, _ = env.step(action)
        episode_reward += reward
        memory_replay.add((state, next_state, action, reward, done))
        if memory_replay.size() > 128:
            if begin_learn is False:
                print('learn begin!')
                begin_learn = True
            learn_steps += 1
            if learn_steps % UPDATE_STEPS == 0:
                targetQNetwork.load_state_dict(onlineQNetwork.state_dict())
            batch = memory_replay.sample(BATCH, False)
            batch_state, batch_next_state, batch_action, batch_reward, batch_done = zip(*batch)

            batch_state = torch.FloatTensor(batch_state).to(device)
            batch_next_state = torch.FloatTensor(batch_next_state).to(device)
            batch_action = torch.FloatTensor(batch_action).unsqueeze(1).to(device)
            batch_reward = torch.FloatTensor(batch_reward).unsqueeze(1).to(device)
            batch_done = torch.FloatTensor(batch_done).unsqueeze(1).to(device)

            with torch.no_grad():
                onlineQ_next = onlineQNetwork(batch_next_state)
                targetQ_next = targetQNetwork(batch_next_state)
                online_max_action = torch.argmax(onlineQ_next, dim=1, keepdim=True)
                y = batch_reward + (1 - batch_done) * GAMMA * targetQ_next.gather(1, online_max_action.long())

            loss = F.mse_loss(onlineQNetwork(batch_state).gather(1, batch_action.long()), y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # writer.add_scalar('loss', loss.item(), global_step=learn_steps)

            if epsilon > FINAL_EPSILON:
                epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        if done:
            break
        state = next_state

    # writer.add_scalar('episode reward', episode_reward, global_step=epoch)
    if epoch % 10 == 0:
        torch.save(onlineQNetwork.state_dict(), 'ddqn-policy.para')
        print('Ep {}\tMoving average score: {:.2f}\t'.format(epoch, episode_reward))
# Out:
# Ep 0	Moving average score: -152.00
# Ep 10	Moving average score: -103.00
# Ep 20	Moving average score: -70.00
# Ep 30	Moving average score: -129.00
# Ep 40	Moving average score: -97.00
# Ep 50	Moving average score: -81.00
# Ep 60	Moving average score: -85.00
# Ep 70	Moving average score: -105.00
# Ep 80	Moving average score: -120.00
# Ep 90	Moving average score: -99.00
# Ep 100	Moving average score: -102.00
# Ep 110	Moving average score: -91.00
# Ep 120	Moving average score: -116.00
# Ep 130	Moving average score: -136.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/vinayak/CS6700/Programming Assignment 2/Duel_DQN_Acrobat.ipynb Cell 6 in 7
#       <a href='vscode-notebook-cell:/home/vinayak/CS6700/Programming%20Assignment%202/Duel_DQN_Acrobat.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> for time_steps in range(200):
#       <a href='vscode-notebook-cell:/home/vinayak/CS6700/Programming%20Assignment%202/Duel_DQN_Acrobat.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     p = random.random()
# ----> <a href='vscode-notebook-cell:/home/vinayak/CS6700/Programming%20Assignment%202/Duel_DQN_Acrobat.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>     _ = env.render()
#       <a href='vscode-notebook-cell:/home/vinayak/CS6700/Programming%20Assignment%202/Duel_DQN_Acrobat.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     if p < epsilon:
#       <a href='vscode-notebook-cell:/home/vinayak/CS6700/Programming%20Assignment%202/Duel_DQN_Acrobat.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>         action = random.randint(0, 2)
#
# File ~/.local/lib/python3.8/site-packages/gym/core.py:235, in Wrapper.render(self, mode, **kwargs)
#     234 def render(self, mode='human', **kwargs):
# --> 235     return self.env.render(mode, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/gym/envs/classic_control/acrobot.py:209, in AcrobotEnv.render(self, mode)
#     206     circ.set_color(.8, .8, 0)
#     207     circ.add_attr(jtransform)
# --> 209 return self.viewer.render(return_rgb_array = mode=='rgb_array')
#
# File ~/.local/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py:114, in Viewer.render(self, return_rgb_array)
#     112     arr = arr.reshape(buffer.height, buffer.width, 4)
#     113     arr = arr[::-1,:,0:3]
# --> 114 self.window.flip()
#     115 self.onetime_geoms = []
#     116 return arr if return_rgb_array else self.isopen
#
# File ~/.local/lib/python3.8/site-packages/pyglet/window/xlib/__init__.py:489, in XlibWindow.flip(self)
#     487 # TODO canvas.flip?
#     488 if self.context:
# --> 489     self.context.flip()
#     491 self._sync_resize()
#
# File ~/.local/lib/python3.8/site-packages/pyglet/gl/xlib.py:376, in XlibContext13.flip(self)
#     374 if self._vsync:
#     375     self._wait_vsync()
# --> 376 glx.glXSwapBuffers(self.x_display, self.glx_window)
#
# KeyboardInterrupt:
